# %%
import xlsxwriter

# %%
workbook = xlsxwriter.Workbook('report.xlsx')
worksheet = workbook.add_worksheet()

worksheet.insert_image('B2', r"C:\Users\DELL\OneDrive\Desktop\Python_Projects\Charts\boston_barplot_rad.png")

workbook.close()
